# %%
import json

# %%
with open('API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.json','r') as j:
    contents=json.loads(j.read())

# %%
type(contents)
# Out:
# list

# %%
import pandas as pd

# %%
#creating dataframe
df=pd.DataFrame(contents)

# %%
df.head()
# Out:
#                             0             1   \
# 0            Last Updated Date    2022-07-20
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
#
#                                                   2                  3   \
# 0
# 1                                     Indicator Name     Indicator Code
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#        4       5       6       7       8       9   ...                57  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# ...

# %%
# drop indexes
df.drop(index=0,inplace=True)

# %%
#renaming that indexes to first row names
df1=df.rename(columns=df.iloc[0])
df1.head()
# Out:
#                   Country Name  Country Code  \
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
# 5   Africa Western and Central           AFW
#
#                                       Indicator Name     Indicator Code  \
# 1                                     Indicator Name     Indicator Code
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#    1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013  \
# 1  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# ...

# %%
#DROP THE FIRST INDEX
df1.drop(index=1,inplace=True)

# %%
df1.head()
# Out:
#                   Country Name Country Code  \
# 2                        Aruba          ABW
# 3  Africa Eastern and Southern          AFE
# 4                  Afghanistan          AFG
# 5   Africa Western and Central          AFW
# 6                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 6  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#    1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013  \
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# 3     NaN     NaN     NaN     NaN     NaN     NaN  ...  18.6635016376268
# ...

# %% [markdown]
# # data cleaning

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 2 to 267
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960.0          0 non-null      float64
#  5   1961.0          0 non-null      float64
#  6   1962.0          0 non-null      float64
#  7   1963.0          0 non-null      float64
#  8   1964.0          0 non-null      float64
#  9   1965.0          0 non-null      float64
#  10  1966.0          0 non-null      float64
#  11  1967.0          0 non-null      float64
#  12  1968.0          0 non-null      float64
#  13  1969.0          0 non-null      float64
#  14  1970.0          0 non-null      float64
#  15  1971.0          0 non-null      float64
#  16  1972.0          0 non-null      float64
# ...

# %%
df1.shape
# Out:
# (266, 67)

# %%
df1.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  1960.0,           1961.0,           1962.0,           1963.0,
#                  1964.0,           1965.0,           1966.0,           1967.0,
#                  1968.0,           1969.0,           1970.0,           1971.0,
#                  1972.0,           1973.0,           1974.0,           1975.0,
#                  1976.0,           1977.0,           1978.0,           1979.0,
#                  1980.0,           1981.0,           1982.0,           1983.0,
#                  1984.0,           1985.0,           1986.0,           1987.0,
#                  1988.0,           1989.0,           '1990',           '1991',
#                  '1992',           '1993',           '1994',           '1995',
#                  '1996',           '1997',           '1998',           '1999',
#                  '2000',           '2001',           '2002',           '2003',
# ...

# %%
df2=df1.drop(columns=[1960.0,           1961.0,           1962.0,           1963.0,
                 1964.0,           1965.0,           1966.0,           1967.0,
                 1968.0,           1969.0,           1970.0,           1971.0,
                 1972.0,           1973.0,           1974.0,           1975.0,
                 1976.0,           1977.0,           1978.0,           1979.0,
                 1980.0,           1981.0,           1982.0,           1983.0,
                 1984.0,           1985.0,           1986.0,           1987.0,
                 1988.0,           1989.0,           2021.0])

# %%
df2.head()
# Out:
#                   Country Name Country Code  \
# 2                        Aruba          ABW
# 3  Africa Eastern and Southern          AFE
# 4                  Afghanistan          AFG
# 5   Africa Western and Central          AFW
# 6                       Angola          AGO
#
#                                       Indicator Name     Indicator Code 1990  \
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS  100
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 6  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#                1991              1992              1993              1994  \
# 2  98.3737741616736  98.4282597493425  98.5017492013514               100
# 3
# 4
# 5                                      12.1566498971678  12.4645979175816
# 6
#
# ...

# %%
df2.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
#                   0
# dtype: int64

# %%
df3=pd.read_csv('C:\\Users\\USER\\Downloads\\Metadata_Country_API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.csv')

# %%
df3.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
df3.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
for i in df3.columns:
    print(df3[i].value_counts())
    print('....................................')
# Out:
# ABW    1
# OSS    1
# MYS    1
# NAC    1
# NAM    1
#       ..
# GUY    1
# HIC    1
# HKG    1
# HND    1
# ZWE    1
# Name: Country Code, Length: 265, dtype: int64
# ....................................
# Europe & Central Asia         58
# Sub-Saharan Africa            48
# Latin America & Caribbean     42
# East Asia & Pacific           37
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: Region, dtype: int64
# ....................................
# High income            80
# Lower middle income    54
# Upper middle income    54
# Low income             28
# Name: IncomeGroup, dtype: int64
# ....................................
# ...

# %%
df3.drop(columns='Unnamed: 5',inplace=True)

# %%
df3.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
df3.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# dtype: int64

# %%
df3['SpecialNotes'].fillna(df3['SpecialNotes'].mode()[0],inplace=True)

# %%
df3['IncomeGroup'].fillna(df3['IncomeGroup'].mode()[0],inplace=True)

# %%
df3['Region'].fillna(df3['Region'].mode()[0],inplace=True)

# %%
df3.isna().sum()
# Out:
# Country Code    0
# Region          0
# IncomeGroup     0
# SpecialNotes    0
# TableName       0
# dtype: int64

# %%
for i in df3.columns:
    print(df[i].value_counts())
    print('..................................')
# Out:
# ABW    1
# OSS    1
# MYS    1
# NAC    1
# NAM    1
#       ..
# GUY    1
# HIC    1
# HKG    1
# HND    1
# ZWE    1
# Name: Country Code, Length: 265, dtype: int64
# ..................................
# Europe & Central Asia         106
# Sub-Saharan Africa             48
# Latin America & Caribbean      42
# East Asia & Pacific            37
# Middle East & North Africa     21
# South Asia                      8
# North America                   3
# Name: Region, dtype: int64
# ..................................
# High income            129
# Lower middle income     54
# Upper middle income     54
# Low income              28
# Name: IncomeGroup, dtype: int64
# ..................................
# ...

# %%
df4=pd.read_csv('C:\\Users\\USER\\Downloads\\Metadata_Indicator_API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.csv')

# %%
df4
# Out:
#       INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  EG.ELC.ACCS.RU.ZS  Access to electricity, rural (% of rural popul...
#
#                                          SOURCE_NOTE  \
# 0  Access to electricity, rural is the percentage...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  World Bank Global Electrification Database fro...         NaN

# %%
df4.isna().sum()
# Out:
# INDICATOR_CODE         0
# INDICATOR_NAME         0
# SOURCE_NOTE            0
# SOURCE_ORGANIZATION    0
# Unnamed: 4             1
# dtype: int64

# %%
df4.drop(columns='Unnamed: 4',inplace=True)

# %%
df4
# Out:
#       INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  EG.ELC.ACCS.RU.ZS  Access to electricity, rural (% of rural popul...
#
#                                          SOURCE_NOTE  \
# 0  Access to electricity, rural is the percentage...
#
#                                  SOURCE_ORGANIZATION
# 0  World Bank Global Electrification Database fro...

# %%
df4['INDICATOR_CODE']
# Out:
# 0    EG.ELC.ACCS.RU.ZS
# Name: INDICATOR_CODE, dtype: object

# %%
df4.isna().sum()
# Out:
# INDICATOR_CODE         0
# INDICATOR_NAME         0
# SOURCE_NOTE            0
# SOURCE_ORGANIZATION    0
# dtype: int64

# %%
df5=df2.merge(df4, left_on='Indicator Code', right_on='INDICATOR_CODE')

# %%
df5.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code 1990  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS  100
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#                1991              1992              1993              1994  \
# 0  98.3737741616736  98.4282597493425  98.5017492013514               100
# 1
# 2
# 3                                      12.1566498971678  12.4645979175816
# 4
#
# ...

# %%
df=df5.merge(df3, left_on='Country Code', right_on='Country Code')

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code 1990  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS  100
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#                1991              1992              1993              1994  \
# 0  98.3737741616736  98.4282597493425  98.5017492013514               100
# 1
# 2
# 3                                      12.1566498971678  12.4645979175816
# 4
#
# ...

# %%
df.isna().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1990                   0
# 1991                   0
# 1992                   0
# 1993                   0
# 1994                   0
# 1995                   0
# 1996                   0
# 1997                   0
# 1998                   0
# 1999                   0
# 2000                   0
# 2001                   0
# 2002                   0
# 2003                   0
# 2004                   0
# 2005                   0
# 2006                   0
# 2007                   0
# 2008                   0
# 2009                   0
# 2010                   0
# 2011                   0
# 2012                   0
# 2013                   0
# 2014                   0
# 2015                   0
# 2016                   0
# 2017                   0
# 2018                   0
# 2019                   0
# 2020                   0
#                        0
# INDICATOR_CODE         0
# ...

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...

# %%
df.to_csv('C:\\Users\\USER\\Desktop\\access_to_ele_rural_word.csv')
