# %%
import json

# %%
with open('C:\\Users\\USER\\Downloads\\API_EG.ELC.LOSS.ZS_DS2_en_csv_v2_4357259.json') as j:
    contents=json.loads(j.read())

# %%
type(contents)
# Out:
# list

# %%
import pandas as pd

# %%
df1=pd.DataFrame(contents)

# %%
df1.head()
# Out:
#                             0             1   \
# 0            Last Updated Date    2022-07-20
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
#
#                                                   2               3     4   \
# 0
# 1                                     Indicator Name  Indicator Code  1960
# 2  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 3  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 4  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
#
#      5     6     7     8     9   ...                57                58  \
# 0                                ...
# 1  1961  1962  1963  1964  1965  ...              2013              2014
# 2                                ...
# 3                                ...  10.3931823810978  10.5947656106552
# 4                                ...
#
#        59      60      61      62      63      64      65 66
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  2015.0  2016.0  2017.0  2018.0  2019.0  2020.0  2021.0
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 67 columns]

# %%
df1.drop(index=0,inplace=True)

# %%
df2=df1.rename(columns=df1.iloc[0])
df2.head()
# Out:
#                   Country Name  Country Code  \
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
# 5   Africa Western and Central           AFW
#
#                                       Indicator Name  Indicator Code  1960  \
# 1                                     Indicator Name  Indicator Code  1960
# 2  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 3  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 4  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 5  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
#
#    1961  1962  1963  1964  1965  ...              2013              2014  \
# 1  1961  1962  1963  1964  1965  ...              2013              2014
# 2                                ...
# 3                                ...  10.3931823810978  10.5947656106552
# 4                                ...
# 5                                ...  18.2006600449596  17.9031474055171
#
#    2015.0  2016.0  2017.0  2018.0  2019.0  2020.0  2021.0
# 1  2015.0  2016.0  2017.0  2018.0  2019.0  2020.0  2021.0
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 67 columns]

# %%
df2.drop(index=1,inplace=True)

# %%
df2.head()
# Out:
#                   Country Name Country Code  \
# 2                        Aruba          ABW
# 3  Africa Eastern and Southern          AFE
# 4                  Afghanistan          AFG
# 5   Africa Western and Central          AFW
# 6                       Angola          AGO
#
#                                       Indicator Name  Indicator Code 1960  \
# 2  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 3  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 4  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 5  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 6  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
#
#   1961 1962 1963 1964 1965  ...              2013              2014 2015.0  \
# 2                           ...                                        NaN
# 3                           ...  10.3931823810978  10.5947656106552    NaN
# 4                           ...                                        NaN
# 5                           ...  18.2006600449596  17.9031474055171    NaN
# 6                           ...  11.2706913339825  11.2658227848101    NaN
#
#   2016.0 2017.0 2018.0 2019.0 2020.0 2021.0
# 2    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN
# 5    NaN    NaN    NaN    NaN    NaN    NaN
# 6    NaN    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # data cleaning

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 2 to 267
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            266 non-null    object
#  5   1961            266 non-null    object
#  6   1962            266 non-null    object
#  7   1963            266 non-null    object
#  8   1964            266 non-null    object
#  9   1965            266 non-null    object
#  10  1966            266 non-null    object
#  11  1967            266 non-null    object
#  12  1968            266 non-null    object
#  13  1969            266 non-null    object
#  14  1970            266 non-null    object
#  15  1971            266 non-null    object
#  16  1972            266 non-null    object
#  17  1973            266 non-null    object
#  18  1974            266 non-null    object
#  19  1975            266 non-null    object
#  20  1976            266 non-null    object
#  21  1977            266 non-null    object
#  22  1978            266 non-null    object
#  23  1979            266 non-null    object
#  24  1980            266 non-null    object
#  25  1981            266 non-null    object
#  26  1982            266 non-null    object
#  27  1983            266 non-null    object
#  28  1984            266 non-null    object
#  29  1985            266 non-null    object
#  30  1986            266 non-null    object
#  31  1987            266 non-null    object
#  32  1988            266 non-null    object
#  33  1989            266 non-null    object
#  34  1990            266 non-null    object
#  35  1991            266 non-null    object
#  36  1992            266 non-null    object
#  37  1993            266 non-null    object
#  38  1994            266 non-null    object
#  39  1995            266 non-null    object
#  40  1996            266 non-null    object
#  41  1997            266 non-null    object
#  42  1998            266 non-null    object
#  43  1999            266 non-null    object
#  44  2000            266 non-null    object
#  45  2001            266 non-null    object
#  46  2002            266 non-null    object
#  47  2003            266 non-null    object
#  48  2004            266 non-null    object
#  49  2005            266 non-null    object
#  50  2006            266 non-null    object
#  51  2007            266 non-null    object
#  52  2008            266 non-null    object
#  53  2009            266 non-null    object
#  54  2010            266 non-null    object
#  55  2011            266 non-null    object
#  56  2012            266 non-null    object
#  57  2013            266 non-null    object
#  58  2014            266 non-null    object
#  59  2015.0          0 non-null      float64
#  60  2016.0          0 non-null      float64
#  61  2017.0          0 non-null      float64
#  62  2018.0          0 non-null      float64
#  63  2019.0          0 non-null      float64
#  64  2020.0          0 non-null      float64
#  65  2021.0          0 non-null      float64
#  66                  266 non-null    object
# dtypes: float64(7), object(60)
# memory usage: 139.4+ KB

# %%
df2.shape
# Out:
# (266, 67)

# %%
df2.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  '1960',           '1961',           '1962',           '1963',
#                  '1964',           '1965',           '1966',           '1967',
#                  '1968',           '1969',           '1970',           '1971',
#                  '1972',           '1973',           '1974',           '1975',
#                  '1976',           '1977',           '1978',           '1979',
#                  '1980',           '1981',           '1982',           '1983',
#                  '1984',           '1985',           '1986',           '1987',
#                  '1988',           '1989',           '1990',           '1991',
#                  '1992',           '1993',           '1994',           '1995',
#                  '1996',           '1997',           '1998',           '1999',
#                  '2000',           '2001',           '2002',           '2003',
#                  '2004',           '2005',           '2006',           '2007',
#                  '2008',           '2009',           '2010',           '2011',
#                  '2012',           '2013',           '2014',           2015.0,
#                  2016.0,           2017.0,           2018.0,           2019.0,
#                  2020.0,           2021.0,               ''],
#       dtype='object')

# %%
df3=df2.drop(columns=[2015.0,
                 2016.0,           2017.0,           2018.0,           2019.0,
                 2020.0,           2021.0])

# %%
df3.head()
# Out:
#                   Country Name Country Code  \
# 2                        Aruba          ABW
# 3  Africa Eastern and Southern          AFE
# 4                  Afghanistan          AFG
# 5   Africa Western and Central          AFW
# 6                       Angola          AGO
#
#                                       Indicator Name  Indicator Code 1960  \
# 2  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 3  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 4  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 5  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 6  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
#
#   1961 1962 1963 1964 1965  ...              2006              2007  \
# 2                           ...
# 3                           ...  9.77220288052724  9.73748538633224
# 4                           ...
# 5                           ...  26.0711049292955  15.6476232010467
# 6                           ...  11.7967332123412  13.3975753807896
#
#                2008              2009              2010              2011  \
# 2
# 3  10.2941131204309  11.2565632867755  10.9606421157655  10.5280813985712
# 4
# 5  16.2822749100932   14.378516957438  18.7269152318124  15.5902043384782
# 6   10.009624639076  10.0105596620908  11.5066984767847  11.2723411785525
#
#                2012              2013              2014
# 2
# 3  10.2766080809619  10.3931823810978  10.5947656106552
# 4
# 5  14.9415374409155  18.2006600449596  17.9031474055171
# 6  11.2669245647969  11.2706913339825  11.2658227848101
#
# [5 rows x 60 columns]

# %%
df3.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
# 1961              0
# 1962              0
# 1963              0
# 1964              0
# 1965              0
# 1966              0
# 1967              0
# 1968              0
# 1969              0
# 1970              0
# 1971              0
# 1972              0
# 1973              0
# 1974              0
# 1975              0
# 1976              0
# 1977              0
# 1978              0
# 1979              0
# 1980              0
# 1981              0
# 1982              0
# 1983              0
# 1984              0
# 1985              0
# 1986              0
# 1987              0
# 1988              0
# 1989              0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
#                   0
# dtype: int64

# %% [markdown]
# import csv files

# %%
df4=pd.read_csv('C:\\Users\\USER\\Downloads\\Metadata_Country_API_EG.ELC.LOSS.ZS_DS2_en_csv_v2_4357259.csv')

# %%
df4.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
df4.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
df4.drop(columns='Unnamed: 5',inplace=True)

# %%
df4['SpecialNotes'].fillna(df4['SpecialNotes'].mode()[0],inplace=True)

# %%
df4['IncomeGroup'].fillna(df4['IncomeGroup'].mode()[0],inplace=True)

# %%
df4['Region'].fillna(df4['Region'].mode()[0],inplace=True)

# %%
for i in df4.columns:
    print(df4[i].value_counts())
    print('....................')
# Out:
# ABW    1
# OSS    1
# MYS    1
# NAC    1
# NAM    1
#       ..
# GUY    1
# HIC    1
# HKG    1
# HND    1
# ZWE    1
# Name: Country Code, Length: 265, dtype: int64
# ....................
# Europe & Central Asia         106
# Sub-Saharan Africa             48
# Latin America & Caribbean      42
# East Asia & Pacific            37
# Middle East & North Africa     21
# South Asia                      8
# North America                   3
# Name: Region, dtype: int64
# ....................
# High income            129
# Lower middle income     54
# Upper middle income     54
# Low income              28
# Name: IncomeGroup, dtype: int64
# ....................
# Fiscal year end: March 31; reporting period for national accounts data: CY.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            146
# The reporting period for national accounts data is designated as either calendar year basis (CY) or fiscal year basis (FY). For this country, it is fiscal year-based (fiscal year-end: June 30). Also, an estimate (PA.NUS.ATLS) of the exchange rate covers the same period and thus differs from the official exchange rate (CY).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     7
# Fiscal year end: June 30; reporting period for national accounts data: CY.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               2
# Fiscal year ends on September 30; reporting period for national accounts data: FY.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       2
# National accounts data are provided in the US dollar.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# The DEC conversion is not reported when national accounts data are unavailable.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# The World Bank systematically assesses the appropriateness of official exchange rates as conversion factors. In this country, multiple or dual exchange rate activity exists and must be accounted for appropriately in underlying statistics. An alternative estimate (“alternative conversion factor” - PA.NUS.ATLS) is thus calculated as a weighted average of the different exchange rates in use in the country. Doing so better reflects economic reality and leads to more accurate cross-country comparisons and country classifications by income level. For this country, this applies to the period 1974-1987. Alternative conversion factors are used in the Atlas methodology and elsewhere in World Development Indicators as single-year conversion factors.                                                                                                                             1
# Includes self-governed areas only, which mostly exclude Abkhazia and South Ossetia, but small areas in Abkhazia and South Ossetia are included before 2008 or 2009 because of the changes in self-governed areas.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Fiscal year ends on September 30; reporting period for national accounts data: FY. The source for national accounts data is the Pacific and Virgin Islands Training Initiative.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# National Accounts data are reported in Zimbabwean Dollar (ZWL). Before 2017, one ZWL is set to be equal to one USD.\n\nThe World Bank systematically assesses the appropriateness of official exchange rates as conversion factors. In this country, multiple or dual exchange rate activity exists and must be accounted for appropriately in underlying statistics. An alternative estimate (“alternative conversion factor” - PA.NUS.ATLS) is thus calculated as a weighted average of the different exchange rates in use in the country. Doing so better reflects economic reality and leads to more accurate cross-country comparisons and country classifications by income level. For this country, this applies to the period 2017-2020. Alternative conversion factors are used in the Atlas methodology and elsewhere in World Development Indicators as single-year conversion factors.      1
# Name: SpecialNotes, Length: 111, dtype: int64
# ....................
# Aruba                   1
# Other small states      1
# Malaysia                1
# North America           1
# Namibia                 1
#                        ..
# Guyana                  1
# High income             1
# Hong Kong SAR, China    1
# Honduras                1
# Zimbabwe                1
# Name: TableName, Length: 265, dtype: int64
# ....................

# %%
df4.isna().sum()
# Out:
# Country Code    0
# Region          0
# IncomeGroup     0
# SpecialNotes    0
# TableName       0
# dtype: int64

# %%
df5=pd.read_csv('C:\\Users\\USER\\Downloads\\Metadata_Indicator_API_EG.ELC.LOSS.ZS_DS2_en_csv_v2_4357259.csv')

# %%
df5.head()
# Out:
#    INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  EG.ELC.LOSS.ZS  Electric power transmission and distribution l...
#
#                                          SOURCE_NOTE  \
# 0  Electric power transmission and distribution l...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  IEA Statistics © OECD/IEA 2018 (http://www.iea...         NaN

# %%
df5.drop(columns='Unnamed: 4',inplace=True)

# %%
df6=df3.merge(df5,left_on='Indicator Code',right_on='INDICATOR_CODE')

# %%
df=df6.merge(df4,left_on='Country Code',right_on='Country Code')

# %%
df.isna().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1960                   0
#                       ..
# SOURCE_ORGANIZATION    0
# Region                 0
# IncomeGroup            0
# SpecialNotes           0
# TableName              0
# Length: 68, dtype: int64

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code 1960  \
# 0    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 1    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 2    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 3    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 4    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# ..                                                 ...             ...  ...
# 260  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 261  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 262  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 263  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
# 264  Electric power transmission and distribution l...  EG.ELC.LOSS.ZS
#
#     1961 1962 1963 1964 1965  ...              2014     INDICATOR_CODE  \
# 0                             ...                       EG.ELC.LOSS.ZS
# 1                             ...  10.5947656106552     EG.ELC.LOSS.ZS
# 2                             ...                       EG.ELC.LOSS.ZS
# 3                             ...  17.9031474055171     EG.ELC.LOSS.ZS
# 4                             ...  11.2658227848101     EG.ELC.LOSS.ZS
# ..   ...  ...  ...  ...  ...  ...               ... ..             ...
# 260                           ...  15.0478292862399     EG.ELC.LOSS.ZS
# 261                           ...  25.7651059377452     EG.ELC.LOSS.ZS
# 262                           ...  8.39376119869644     EG.ELC.LOSS.ZS
# 263                           ...  14.9598671464157     EG.ELC.LOSS.ZS
# 264                           ...  16.4372631158987     EG.ELC.LOSS.ZS
#
#                                         INDICATOR_NAME  \
# 0    Electric power transmission and distribution l...
# 1    Electric power transmission and distribution l...
# 2    Electric power transmission and distribution l...
# 3    Electric power transmission and distribution l...
# 4    Electric power transmission and distribution l...
# ..                                                 ...
# 260  Electric power transmission and distribution l...
# 261  Electric power transmission and distribution l...
# 262  Electric power transmission and distribution l...
# 263  Electric power transmission and distribution l...
# 264  Electric power transmission and distribution l...
#
#                                            SOURCE_NOTE  \
# 0    Electric power transmission and distribution l...
# 1    Electric power transmission and distribution l...
# 2    Electric power transmission and distribution l...
# 3    Electric power transmission and distribution l...
# 4    Electric power transmission and distribution l...
# ..                                                 ...
# 260  Electric power transmission and distribution l...
# 261  Electric power transmission and distribution l...
# 262  Electric power transmission and distribution l...
# 263  Electric power transmission and distribution l...
# 264  Electric power transmission and distribution l...
#
#                                    SOURCE_ORGANIZATION  \
# 0    IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 1    IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 2    IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 3    IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 4    IEA Statistics © OECD/IEA 2018 (http://www.iea...
# ..                                                 ...
# 260  IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 261  IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 262  IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 263  IEA Statistics © OECD/IEA 2018 (http://www.iea...
# 264  IEA Statistics © OECD/IEA 2018 (http://www.iea...
#
#                          Region          IncomeGroup  \
# 0     Latin America & Caribbean          High income
# 1         Europe & Central Asia          High income
# 2                    South Asia           Low income
# 3         Europe & Central Asia          High income
# 4            Sub-Saharan Africa  Lower middle income
# ..                          ...                  ...
# 260       Europe & Central Asia  Upper middle income
# 261  Middle East & North Africa           Low income
# 262          Sub-Saharan Africa  Upper middle income
# 263          Sub-Saharan Africa           Low income
# 264          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0    Fiscal year end: March 31; reporting period fo...
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260  Fiscal year end: March 31; reporting period fo...
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 68 columns]

# %%
df.to_csv('C:\\Users\\USER\\Desktop\\World_Electric_analysis\\access_to_ele_power_tran_dis_loss.csv')
